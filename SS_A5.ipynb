# %% [markdown]
# ## Sana Shaikh - Homework 5 Question 1

# %% [markdown]
# ### A. Download the dataset "Digit" and its label, and import the necessary libraries:

# %%
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Check out the dataset. The goal is to build a Machine Learning Algorithm that can recognize the hand-written digits!

# %%
df = pd.DataFrame()
digit_df = pd.read_csv('/Users/RubaShaikh/Desktop/CS4661-DataScience/label.csv')
digit_df.head()
# Out:
#    name of the file  digit label
# 0                 0            0
# 1                 1            1
# 2                 2            2
# 3                 3            3
# 4                 4            4

# %%
for i in range (10):
    img = mpimg.imread('/Users/RubaShaikh/Desktop/CS4661-DataScience/Digit/' + str(i) + '.jpg')
    plt.imshow(img, cmap=plt.cm.gray_r, interpolation='nearest')
    plt.show()

# %% [markdown]
# ### B. Build the feature matrix and label vector.

# %%
length = len(digit_df.index)
list = []

for x in range(length):
    image = mpimg.imread('/Users/RubaShaikh/Desktop/CS4661-DataScience/Digit/' + str(x) + '.jpg')
    feature = image.reshape(-1)
    list.append(feature)
    #print(list[0:10])

X = np.array(list)
y = digit_df['digit label']
print(X.shape)
print(y.shape)
# Out:
# (1797, 64)
# (1797,)

# %% [markdown]
# ### C.  Use sklearn functions to split the dataset into testing and training sets with the following parameters: test_size=0.1, random_state=2.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1617, 64)
# (180, 64)
# (1617,)
# (180,)

# %% [markdown]
# ### D. Use scikit-learn “Random Forest” classifier to recognize the hand-written digits based on the training/testing datasets that you built in part (c). Use this command to import and define your classifier:
# #### from   sklearn.ensemble    import    RandomForestClassifier
# #### my_RandomForest =
# #### RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=2)
# #### Use my_RandomForest.fit for training your random forest classifier and my_RandomForest.predict  for prediction. Test your Machine Learning Algorithm on testing set (from part(c)), and calculate and report the accuracy.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

my_RandomForest = RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=2)

my_RandomForest.fit(X_train,y_train)
y_predict_rf = my_RandomForest.predict(X_test)

score_rf = accuracy_score(y_test, y_predict_rf)

print('The Accuracy Score for Random Forest is:', score_rf)
# Out:
# The Accuracy Score for Random Forest is: 0.9277777777777778

# %% [markdown]
# ### E. Write some codes to find which one of the data samples (i.e. which images) have been misclassified (classified incorrectly) in your testing set. Then, use the following command to show the misclassified images:    plt.imshow(image_name, cmap=plt.cm.gray_r, interpolation='nearest')

# %%
y_test = np.asarray(y_test)
missclassified_samples = np.where(y_test != y_predict)

for j in missclassified_samples[0]:
    print(y_predict[j])
    pics = mpimg.imread('/Users/SShaikh/Desktop/CS4661-DataScience/Digit/' + str(j) + '.jpg') # directory name
    plt.imshow(pics, cmap=plt.cm.gray_r, interpolation='nearest')
    plt.show()
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
